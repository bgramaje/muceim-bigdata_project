# %%
# %pip install duckdb pandas numpy pyspainmobility
# Out:
# Requirement already satisfied: duckdb in /Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/.venv/lib/python3.13/site-packages (1.4.2)
# Requirement already satisfied: pandas in /Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy in /Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/.venv/lib/python3.13/site-packages (2.3.4)
# Collecting pyspainmobility
#   Downloading pyspainmobility-1.0.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Collecting geopandas~=1.0.1 (from pyspainmobility)
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting tqdm>=4.0.0 (from pyspainmobility)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting matplotlib>=3.0.0 (from pyspainmobility)
#   Downloading matplotlib-3.10.7-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting pyarrow>=8.0.0 (from pyspainmobility)
#   Downloading pyarrow-22.0.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (3.2 kB)
# Collecting dask>=2024.0 (from dask[dataframe]>=2024.0->pyspainmobility)
#   Downloading dask-2025.11.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting pyogrio>=0.7.2 (from geopandas~=1.0.1->pyspainmobility)
#   Downloading pyogrio-0.11.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (5.3 kB)
# Requirement already satisfied: packaging in /Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/.venv/lib/python3.13/site-packages (from geopandas~=1.0.1->pyspainmobility) (25.0)
# Collecting pyproj>=3.3.0 (from geopandas~=1.0.1->pyspainmobility)
#   Downloading pyproj-3.7.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas~=1.0.1->pyspainmobility)
#   Downloading shapely-2.1.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting click>=8.1 (from dask>=2024.0->dask[dataframe]>=2024.0->pyspainmobility)
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting cloudpickle>=3.0.0 (from dask>=2024.0->dask[dataframe]>=2024.0->pyspainmobility)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting fsspec>=2021.09.0 (from dask>=2024.0->dask[dataframe]>=2024.0->pyspainmobility)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting partd>=1.4.0 (from dask>=2024.0->dask[dataframe]>=2024.0->pyspainmobility)
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyyaml>=5.3.1 (from dask>=2024.0->dask[dataframe]>=2024.0->pyspainmobility)
#   Downloading pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting toolz>=0.10.0 (from dask>=2024.0->dask[dataframe]>=2024.0->pyspainmobility)
#   Downloading toolz-1.1.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.0.0->pyspainmobility)
#   Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.0.0->pyspainmobility)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.0.0->pyspainmobility)
#   Downloading fonttools-4.60.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.0.0->pyspainmobility)
#   Downloading kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib>=3.0.0->pyspainmobility)
#   Downloading pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.0.0->pyspainmobility)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting locket (from partd>=1.4.0->dask>=2024.0->dask[dataframe]>=2024.0->pyspainmobility)
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting certifi (from pyogrio>=0.7.2->geopandas~=1.0.1->pyspainmobility)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: six>=1.5 in /Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pyspainmobility-1.0.4-py3-none-any.whl (16 kB)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading dask-2025.11.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.0 MB/s  0:00:00
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Downloading matplotlib-3.10.7-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 10.6 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp313-cp313-macosx_10_13_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 10.5 MB/s  0:00:00 eta 0:00:01
# Downloading kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 10.7 MB/s  0:00:00 eta 0:00:01
# Downloading pyarrow-22.0.0-cp313-cp313-macosx_12_0_arm64.whl (34.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.2/34.2 MB 10.8 MB/s  0:00:03m0:00:0100:01
# Downloading pyogrio-0.11.1-cp313-cp313-macosx_12_0_arm64.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 11.1 MB/s  0:00:01 eta 0:00:01
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading pyproj-3.7.2-cp313-cp313-macosx_14_0_arm64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 10.4 MB/s  0:00:00 eta 0:00:01
# Downloading pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Downloading shapely-2.1.2-cp313-cp313-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.1 MB/s  0:00:00
# Downloading toolz-1.1.0-py3-none-any.whl (58 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: tqdm, toolz, shapely, pyyaml, pyparsing, pyarrow, pillow, locket, kiwisolver, fsspec, fonttools, cycler, contourpy, cloudpickle, click, certifi, pyproj, pyogrio, partd, matplotlib, geopandas, dask, pyspainmobility
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/23 [pyspainmobility] [pyspainmobility]
# Successfully installed certifi-2025.11.12 click-8.3.0 cloudpickle-3.1.2 contourpy-1.3.3 cycler-0.12.1 dask-2025.11.0 fonttools-4.60.1 fsspec-2025.10.0 geopandas-1.0.1 kiwisolver-1.4.9 locket-1.0.0 matplotlib-3.10.7 partd-1.4.2 pillow-12.0.0 pyarrow-22.0.0 pyogrio-0.11.1 pyparsing-3.2.5 pyproj-3.7.2 pyspainmobility-1.0.4 pyyaml-6.0.3 shapely-2.1.2 toolz-1.1.0 tqdm-4.67.1
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb
import pandas

con = duckdb.connect('../bronze.db')

def SQL(q):
    """Run SQL (printed for clarity) and return a DataFrame."""
    return con.execute(q).fetchdf()

print("DuckDB version:", con.sql("SELECT version();").fetchone()[0]) # type: ignore
# Out:
# DuckDB version: v1.4.2

# %% [markdown]
# ```sql
# -- viajes distristos
# -- se castea en vez de VARCHAR de 'si/no' a un booleano de true o false
# -- bronze_mitma_od_districts / bronze_mitma_viajes_distritos
# CREATE TABLE bronze_mitma_od_districts (
#     fecha DATE, -- de TEXT a DATE
#     hora SMALLINT,
#     origen TEXT,
#     destino TEXT,
#     distancia TEXT,
#     actividad_origen TEXT,
#     actividad_destino TEXT,
#     residencia TEXT,
#     renta TEXT,
#     edad TEXT,
#     sexo TEXT,
#     viajes DOUBLE,
#     viajes_km DOUBLE,
#     estudio_destino_posible BOOLEAN,  -- de VARCHAR a BOOLEAN
#     estudio_origen_posible BOOLEAN,   -- de VARCHAR a BOOLEAN
#     -- Columnas extras añadidas para auditoria.
#     loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     -- loaded_by TEXT DEFAULT CURRENT_USER,
#     source_file TEXT
# );
#
# -- Viajes municipios
# -- bronze_mitma_od_municipalities / bronze_mitma_viajes_municipios
# CREATE TABLE bronze_mitma_od_municipalities (
#     fecha DATE,  -- de TEXT a DATE
#     hora SMALLINT,
#     origen TEXT,
#     destino TEXT,
#     distancia TEXT,
#     actividad_origen TEXT,
#     actividad_destino TEXT,
#     residencia TEXT,
#     renta TEXT,
#     edad TEXT,
#     sexo TEXT,
#     viajes DOUBLE,
#     viajes_km DOUBLE,
#     estudio_destino_posible BOOLEAN, -- de VARCHAR a BOOLEAN
#     estudio_origen_posible BOOLEAN,  -- de VARCHAR a BOOLEAN
#     -- auditoria
#     loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     -- loaded_by TEXT DEFAULT CURRENT_USER,
#     source_file TEXT
# );
#
# -- Viajes GAU
# -- bronze_mitma_od_gau / bronze_mitma_viajes_gau
# CREATE TABLE bronze_mitma_od_gau (
#     fecha DATE,  -- de TEXT a DATE
#     hora SMALLINT,
#     origen TEXT,
#     destino TEXT,
#     distancia TEXT,
#     actividad_origen TEXT,
#     actividad_destino TEXT,
#     residencia TEXT,
#     renta TEXT,
#     edad TEXT,
#     sexo TEXT,
#     viajes DOUBLE,
#     viajes_km DOUBLE,
#     estudio_destino_posible BOOLEAN, -- de VARCHAR a BOOLEAN
#     estudio_origen_posible BOOLEAN,  -- de VARCHAR a BOOLEAN
#     -- auditoria
#     loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     -- loaded_by TEXT DEFAULT CURRENT_USER,
#     source_file TEXT
# );
# ```

# %%
from pyspainmobility import Mobility
import os

def load_od_matrices(type = "districts"):
    dataset = 'od'
    os.makedirs(f'../raw/viajes_{type}', exist_ok=True)
    
    if not os.listdir(f'../raw/viajes_{type}'): # only download if the directory is empty
        data = Mobility(
            version=2,
            zones=type,
            start_date='2022-03-01',
            end_date='2022-03-03',
            output_directory=f'/Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/raw/viajes_{type}',
        )
    
        data.get_od_data(keep_activity=True)

    SQL(f"DROP TABLE IF EXISTS bronze_mitma_{dataset}_{type};")
    SQL(f"""
        CREATE TABLE IF NOT EXISTS bronze_mitma_{dataset}_{type}(
            fecha DATE, -- de TEXT a DATE
            hora SMALLINT, -- de TEXT a SMALLINT, de periodo a hora
            origen TEXT,
            destino TEXT,
            distancia TEXT,
            actividad_origen TEXT,
            actividad_destino TEXT,
            residencia TEXT,
            renta TEXT,
            edad TEXT,
            sexo TEXT,
            viajes DOUBLE,
            viajes_km DOUBLE,
            estudio_destino_posible BOOLEAN,  -- de VARCHAR a BOOLEAN
            estudio_origen_posible BOOLEAN,   -- de VARCHAR a BOOLEAN
            -- Columnas extras añadidas para auditoria. 
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            -- loaded_by TEXT DEFAULT CURRENT_USER,
            source_file TEXT
        );
    """)

    SQL(f"""
        INSERT INTO bronze_mitma_{dataset}_{type}
        SELECT
            strptime(CAST(fecha AS VARCHAR), '%Y%m%d')::DATE AS fecha,
            CAST(periodo AS SMALLINT) AS hora,
            origen,
            destino,
            distancia,
            actividad_origen,
            actividad_destino,
            residencia,
            renta,
            edad,
            sexo,
            CAST(viajes AS DOUBLE) AS viajes,
            CAST(viajes_km AS DOUBLE) AS viajes_km,
            CASE 
                WHEN estudio_destino_posible IN ('si', 'SI', 'sí') THEN TRUE 
                WHEN estudio_destino_posible IN ('no', 'NO') THEN FALSE 
                ELSE NULL
            END AS estudio_destino_posible,
            CASE 
                WHEN estudio_origen_posible IN ('si', 'SI', 'sí') THEN TRUE 
                WHEN estudio_origen_posible IN ('no', 'NO') THEN FALSE 
                ELSE NULL
            END AS estudio_origen_posible,
            CURRENT_TIMESTAMP AS loaded_at,
            -- CURRENT_USER AS loaded_by,
            filename AS source_file
        FROM read_csv(
            '../raw/viajes_{type}/*.csv.gz',
            filename = true,
            all_varchar = true
        );
 
""")

# %%
load_od_matrices(type="distritos")
load_od_matrices(type="municipios")
load_od_matrices(type="gau")

# %%
SQL("SELECT * FROM bronze_mitma_od_municipios LIMIT 5;")
# Out:
#        fecha  hora origen   destino distancia actividad_origen  \
# 0 2022-03-01     0  01001  01009_AM      2-10             casa
# 1 2022-03-01     0  01001  01009_AM      2-10        frecuente
# 2 2022-03-01     0  01001  01058_AM     10-50        frecuente
# 3 2022-03-01     0  01001  01058_AM      2-10        frecuente
# 4 2022-03-01     0  01001     01059     10-50        frecuente
#
#   actividad_destino residencia  renta  edad   sexo  viajes  viajes_km  \
# 0         frecuente         01  10-15    NA     NA  10.279     67.832
# 1              casa         01    >15    NA     NA   4.591     42.419
# 2      no_frecuente         01    >15    NA     NA   4.773     72.081
# 3              casa         01    >15    NA     NA   1.739     15.513
# 4              casa         01    >15  0-25  mujer  12.318    155.587
#
#    estudio_destino_posible  estudio_origen_posible                  loaded_at  \
# 0                    False                   False 2025-11-15 22:51:17.350963
# 1                    False                   False 2025-11-15 22:51:17.350963
# 2                    False                   False 2025-11-15 22:51:17.350963
# 3                    False                   False 2025-11-15 22:51:17.350963
# 4                    False                   False 2025-11-15 22:51:17.350963
#
#                                          source_file
# 0  ../raw/viajes_municipios/20220301_Viajes_munic...
# 1  ../raw/viajes_municipios/20220301_Viajes_munic...
# 2  ../raw/viajes_municipios/20220301_Viajes_munic...
# 3  ../raw/viajes_municipios/20220301_Viajes_munic...
# 4  ../raw/viajes_municipios/20220301_Viajes_munic...

# %%
SQL("SELECT * FROM bronze_mitma_od_gau LIMIT 5;")
# Out:
#        fecha  hora origen              destino distancia actividad_origen  \
# 0 2022-03-01     0  01001             01009_AM      2-10             casa
# 1 2022-03-01     0  01001             01009_AM      2-10        frecuente
# 2 2022-03-01     0  01001             01058_AM     10-50        frecuente
# 3 2022-03-01     0  01001             01058_AM      2-10        frecuente
# 4 2022-03-01     0  01001  GAU Vitoria/Gasteiz     10-50        frecuente
#
#   actividad_destino residencia  renta  edad   sexo  viajes  viajes_km  \
# 0         frecuente         01  10-15    NA     NA  10.279     67.832
# 1              casa         01    >15    NA     NA   4.591     42.419
# 2      no_frecuente         01    >15    NA     NA   4.773     72.081
# 3              casa         01    >15    NA     NA   1.739     15.513
# 4              casa         01    >15  0-25  mujer  12.318    155.587
#
#    estudio_destino_posible  estudio_origen_posible                  loaded_at  \
# 0                    False                   False 2025-11-15 22:51:57.938569
# 1                    False                   False 2025-11-15 22:51:57.938569
# 2                    False                   False 2025-11-15 22:51:57.938569
# 3                    False                   False 2025-11-15 22:51:57.938569
# 4                    False                   False 2025-11-15 22:51:57.938569
#
#                                        source_file
# 0  ../raw/viajes_gau/20220301_Viajes_GAU_v2.csv.gz
# 1  ../raw/viajes_gau/20220301_Viajes_GAU_v2.csv.gz
# 2  ../raw/viajes_gau/20220301_Viajes_GAU_v2.csv.gz
# 3  ../raw/viajes_gau/20220301_Viajes_GAU_v2.csv.gz
# 4  ../raw/viajes_gau/20220301_Viajes_GAU_v2.csv.gz

# %%
# todo, altera table para llamar periodo a hora, esta la columna creada con periodo en vez de hora
SQL("SELECT * FROM bronze_mitma_od_distritos LIMIT 5;")
# Out:
#        fecha  hora origen   destino distancia actividad_origen  \
# 0 2022-03-01     8  01001     01002     10-50             casa
# 1 2022-03-01    17  01001     01002     10-50     no_frecuente
# 2 2022-03-01     0  01001  01009_AM      2-10             casa
# 3 2022-03-01     0  01001  01009_AM      2-10        frecuente
# 4 2022-03-01     2  01001  01009_AM      2-10             casa
#
#   actividad_destino residencia  renta edad sexo  viajes  viajes_km  \
# 0         frecuente         01  10-15   NA   NA   2.764    125.486
# 1              casa         01  10-15   NA   NA   6.526    303.751
# 2         frecuente         01  10-15   NA   NA  10.279     67.832
# 3              casa         01    >15   NA   NA   4.591     42.419
# 4         frecuente         01  10-15   NA   NA   2.539     13.819
#
#    estudio_destino_posible  estudio_origen_posible                  loaded_at  \
# 0                    False                   False 2025-11-15 22:50:14.404164
# 1                    False                   False 2025-11-15 22:50:14.404164
# 2                    False                   False 2025-11-15 22:50:14.404164
# 3                    False                   False 2025-11-15 22:50:14.404164
# 4                    False                   False 2025-11-15 22:50:14.404164
#
#                                          source_file
# 0  ../raw/viajes_distritos/20220301_Viajes_distri...
# 1  ../raw/viajes_distritos/20220301_Viajes_distri...
# 2  ../raw/viajes_distritos/20220301_Viajes_distri...
# 3  ../raw/viajes_distritos/20220301_Viajes_distri...
# 4  ../raw/viajes_distritos/20220301_Viajes_distri...

# %% [markdown]
# ```sql
# -- Distritos
# CREATE TABLE IF NOT EXISTS bronze_mitma_people_day_districts (
#   fecha DATE,
#   zona_pernoctacion TEXT,
#   edad TEXT,
#   sexo TEXT,
#   numero_viajes TEXT,   -- 0,1,2,2+ (mantener TEXT)
#   personas DOUBLE,
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
#
# -- Municipios
# CREATE TABLE IF NOT EXISTS bronze_mitma_people_day_municipalities (
#   fecha DATE,
#   zona_pernoctacion TEXT,
#   edad TEXT,
#   sexo TEXT,
#   numero_viajes TEXT,
#   personas DOUBLE,
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
#
# -- GAU
# CREATE TABLE IF NOT EXISTS bronze_mitma_people_day_gau (
#   fecha DATE,
#   zona_pernoctacion TEXT,
#   edad TEXT,
#   sexo TEXT,
#   numero_viajes TEXT,
#   personas DOUBLE,
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );

# %%
from pyspainmobility import Mobility
import os

def load_people_day(type = "districts", start_date='2022-03-01', end_date='2022-03-03'):
    dataset = 'people_day'
    dataset_path = f'../raw/{dataset}_{type}'
    table_name = f'bronze_mitma_{dataset}_{type}'

    os.makedirs(dataset_path, exist_ok=True)
    
    if not os.listdir(dataset_path): # only download if the directory is empty
        data = Mobility(
            version=2,
            zones=type,
            start_date=start_date,
            end_date=end_date,
            output_directory=f'/Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/raw/{dataset}_{type}',
        )
    
        data.get_number_of_trips_data()

    SQL(f"DROP TABLE IF EXISTS {table_name};")
    SQL(f"""
        CREATE TABLE IF NOT EXISTS {table_name}(
            fecha DATE,
            zona_pernoctacion TEXT,
            edad TEXT,
            sexo TEXT,
            numero_viajes TEXT,
            personas DOUBLE,
            -- Columnas extras añadidas para auditoria. 
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            -- loaded_by TEXT DEFAULT CURRENT_USER,
            source_file TEXT
        );
    """)

    SQL(f"""
        INSERT INTO {table_name}
        SELECT
            strptime(CAST(fecha AS VARCHAR), '%Y%m%d')::DATE AS fecha,
            zona_pernoctacion,
            edad,
            sexo,
            numero_viajes,
            CAST(personas AS DOUBLE) AS personas,
            CURRENT_TIMESTAMP AS loaded_at,
            -- CURRENT_USER AS loaded_by,
            filename AS source_file
        FROM read_csv(
            '{dataset_path}/*.csv.gz',
            filename = true,
            all_varchar = true
        );
 
""")

# %%
load_people_day(type="distritos")
load_people_day(type="municipios")
load_people_day(type="gau")

# %%
SQL("SELECT * FROM bronze_mitma_people_day_distritos LIMIT 5;")
# Out:
#        fecha zona_pernoctacion  edad    sexo numero_viajes  personas  \
# 0 2022-03-01             01001  0-25  hombre             0   125.296
# 1 2022-03-01             01001  0-25  hombre             2   115.378
# 2 2022-03-01             01001  0-25  hombre            2+   176.630
# 3 2022-03-01             01001  0-25   mujer             0   125.069
# 4 2022-03-01             01001  0-25   mujer             2   117.712
#
#                    loaded_at  \
# 0 2025-11-16 09:18:07.482225
# 1 2025-11-16 09:18:07.482225
# 2 2025-11-16 09:18:07.482225
# 3 2025-11-16 09:18:07.482225
# 4 2025-11-16 09:18:07.482225
#
#                                          source_file
# 0  ../raw/people_day_distritos/20220301_Personas_...
# 1  ../raw/people_day_distritos/20220301_Personas_...
# 2  ../raw/people_day_distritos/20220301_Personas_...
# 3  ../raw/people_day_distritos/20220301_Personas_...
# 4  ../raw/people_day_distritos/20220301_Personas_...

# %%
SQL("SELECT * FROM bronze_mitma_people_day_municipios LIMIT 5;")
# Out:
#        fecha zona_pernoctacion  edad    sexo numero_viajes  personas  \
# 0 2022-03-01             01001  0-25  hombre             0   125.296
# 1 2022-03-01             01001  0-25  hombre             2   115.378
# 2 2022-03-01             01001  0-25  hombre            2+   176.630
# 3 2022-03-01             01001  0-25   mujer             0   125.069
# 4 2022-03-01             01001  0-25   mujer             2   117.712
#
#                    loaded_at  \
# 0 2025-11-16 09:18:11.377297
# 1 2025-11-16 09:18:11.377297
# 2 2025-11-16 09:18:11.377297
# 3 2025-11-16 09:18:11.377297
# 4 2025-11-16 09:18:11.377297
#
#                                          source_file
# 0  ../raw/people_day_municipios/20220301_Personas...
# 1  ../raw/people_day_municipios/20220301_Personas...
# 2  ../raw/people_day_municipios/20220301_Personas...
# 3  ../raw/people_day_municipios/20220301_Personas...
# 4  ../raw/people_day_municipios/20220301_Personas...

# %%
SQL("SELECT * FROM bronze_mitma_people_day_gau LIMIT 5;")
# Out:
#        fecha zona_pernoctacion  edad    sexo numero_viajes  personas  \
# 0 2022-03-01             01001  0-25  hombre             0   125.296
# 1 2022-03-01             01001  0-25  hombre             2   115.378
# 2 2022-03-01             01001  0-25  hombre            2+   176.630
# 3 2022-03-01             01001  0-25   mujer             0   125.069
# 4 2022-03-01             01001  0-25   mujer             2   117.712
#
#                    loaded_at  \
# 0 2025-11-16 09:18:14.943879
# 1 2025-11-16 09:18:14.943879
# 2 2025-11-16 09:18:14.943879
# 3 2025-11-16 09:18:14.943879
# 4 2025-11-16 09:18:14.943879
#
#                                          source_file
# 0  ../raw/people_day_gau/20220301_Personas_GAU_v2...
# 1  ../raw/people_day_gau/20220301_Personas_GAU_v2...
# 2  ../raw/people_day_gau/20220301_Personas_GAU_v2...
# 3  ../raw/people_day_gau/20220301_Personas_GAU_v2...
# 4  ../raw/people_day_gau/20220301_Personas_GAU_v2...

# %% [markdown]
# ```sql
# -- Distritos
# CREATE TABLE IF NOT EXISTS bronze_mitma_overnight_stay_districts (
#   fecha DATE,
#   zona_residencia TEXT,
#   zona_pernoctacion TEXT,
#   personas DOUBLE,
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
#
# -- Municipios
# CREATE TABLE IF NOT EXISTS bronze_mitma_overnight_stay_municipalities (
#   fecha DATE,
#   zona_residencia TEXT,
#   zona_pernoctacion TEXT,
#   personas DOUBLE,
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
#
# -- GAU
# CREATE TABLE IF NOT EXISTS bronze_mitma_overnight_stay_gau (
#   fecha DATE,
#   zona_residencia TEXT,
#   zona_pernoctacion TEXT,
#   personas DOUBLE,
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );

# %%
from pyspainmobility import Mobility
import os

def load_overnight_stay(type = "districts", start_date='2022-03-01', end_date='2022-03-03'):
    dataset = 'overnight_stay'
    dataset_path = f'../raw/{dataset}_{type}'
    table_name = f'bronze_mitma_{dataset}_{type}'

    os.makedirs(dataset_path, exist_ok=True)
    
    if not os.listdir(dataset_path): # only download if the directory is empty
        data = Mobility(
            version=2,
            zones=type,
            start_date=start_date,
            end_date=end_date,
            output_directory=f'/Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/raw/{dataset}_{type}',
        )
    
        data.get_overnight_stays_data()

    SQL(f"DROP TABLE IF EXISTS {table_name};")
    SQL(f"""
        CREATE TABLE IF NOT EXISTS {table_name}(
            fecha DATE,
            zona_residencia TEXT,
            zona_pernoctacion TEXT,
            personas DOUBLE,
            -- Columnas extras añadidas para auditoria. 
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            -- loaded_by TEXT DEFAULT CURRENT_USER,
            source_file TEXT
        );
    """)

    SQL(f"""
        INSERT INTO {table_name}
        SELECT
            strptime(CAST(fecha AS VARCHAR), '%Y%m%d')::DATE AS fecha,
            zona_residencia,
            zona_pernoctacion,
            CAST(personas AS DOUBLE) AS personas,
            CURRENT_TIMESTAMP AS loaded_at,
            -- CURRENT_USER AS loaded_by,
            filename AS source_file
        FROM read_csv(
            '{dataset_path}/*.csv.gz',
            filename = true,
            all_varchar = true
        );
 
""")

# %%
load_overnight_stay(type="distritos")
load_overnight_stay(type="municipios")
load_overnight_stay(type="gau")

# %%
SQL("SELECT * FROM bronze_mitma_overnight_stay_distritos LIMIT 5;")
# Out:
#        fecha zona_residencia zona_pernoctacion  personas  \
# 0 2022-03-01           01001             01001  2733.784
# 1 2022-03-01           01001          01004_AM     2.514
# 2 2022-03-01           01001          01009_AM    18.431
# 3 2022-03-01           01001          01017_AM     2.922
# 4 2022-03-01           01001             01051     7.831
#
#                    loaded_at  \
# 0 2025-11-16 09:24:52.111616
# 1 2025-11-16 09:24:52.111616
# 2 2025-11-16 09:24:52.111616
# 3 2025-11-16 09:24:52.111616
# 4 2025-11-16 09:24:52.111616
#
#                                          source_file
# 0  ../raw/overnight_stay_distritos/20220301_Perno...
# 1  ../raw/overnight_stay_distritos/20220301_Perno...
# 2  ../raw/overnight_stay_distritos/20220301_Perno...
# 3  ../raw/overnight_stay_distritos/20220301_Perno...
# 4  ../raw/overnight_stay_distritos/20220301_Perno...

# %%
SQL("SELECT * FROM bronze_mitma_overnight_stay_municipios LIMIT 5;")
# Out:
#        fecha zona_residencia zona_pernoctacion  personas  \
# 0 2022-03-01           01001             01001  2733.784
# 1 2022-03-01           01001          01004_AM     2.514
# 2 2022-03-01           01001          01009_AM    18.431
# 3 2022-03-01           01001          01017_AM     2.922
# 4 2022-03-01           01001             01051     7.831
#
#                    loaded_at  \
# 0 2025-11-16 09:24:56.575760
# 1 2025-11-16 09:24:56.575760
# 2 2025-11-16 09:24:56.575760
# 3 2025-11-16 09:24:56.575760
# 4 2025-11-16 09:24:56.575760
#
#                                          source_file
# 0  ../raw/overnight_stay_municipios/20220301_Pern...
# 1  ../raw/overnight_stay_municipios/20220301_Pern...
# 2  ../raw/overnight_stay_municipios/20220301_Pern...
# 3  ../raw/overnight_stay_municipios/20220301_Pern...
# 4  ../raw/overnight_stay_municipios/20220301_Pern...

# %%
SQL("SELECT * FROM bronze_mitma_overnight_stay_gau LIMIT 5;")
# Out:
#        fecha zona_residencia zona_pernoctacion  personas  \
# 0 2022-03-01           01001             01001  2733.784
# 1 2022-03-01           01001          01004_AM     2.514
# 2 2022-03-01           01001          01009_AM    18.431
# 3 2022-03-01           01001          01017_AM     2.922
# 4 2022-03-01           01001             01051     7.831
#
#                    loaded_at  \
# 0 2025-11-16 09:25:00.656147
# 1 2025-11-16 09:25:00.656147
# 2 2025-11-16 09:25:00.656147
# 3 2025-11-16 09:25:00.656147
# 4 2025-11-16 09:25:00.656147
#
#                                          source_file
# 0  ../raw/overnight_stay_gau/20220301_Pernoctacio...
# 1  ../raw/overnight_stay_gau/20220301_Pernoctacio...
# 2  ../raw/overnight_stay_gau/20220301_Pernoctacio...
# 3  ../raw/overnight_stay_gau/20220301_Pernoctacio...
# 4  ../raw/overnight_stay_gau/20220301_Pernoctacio...

# %% [markdown]
# ```sql
# -- Distritos
# CREATE TABLE IF NOT EXISTS bronze_mitma_districts (
#   id TEXT,
#   name TEXT,
#   population DOUBLE,
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
#
# -- Municipios
# CREATE TABLE IF NOT EXISTS bronze_mitma_municipalities (
#   id TEXT,
#   name TEXT,
#   population DOUBLE,
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
#
# -- GAU
# CREATE TABLE IF NOT EXISTS bronze_mitma_gau (
#   id TEXT,
#   name TEXT,
#   population DOUBLE,
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );

# %%
# %load_ext autoreload

# %%
# %autoreload 2

from pyspainmobility import Zones
import os
import pandas as pd

def load_zones(type = "districts"):
    dataset_path = f'../raw/{type}'
    table_name = f'bronze_mitma_{type}'

    os.makedirs(dataset_path, exist_ok=True)
    
    if(not os.path.isfile(f'{dataset_path}/zones.csv.gz')):
        data = Zones(
                version=2,
                zones=type,
                output_directory=f'/Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/raw/{type}',
            )
        
        dfdata = data.get_zone_geodataframe()
        if dfdata is not None:
            dfdata.to_csv(f'{dataset_path}/zones.csv.gz', index=False, compression='gzip')
        else:
            raise ValueError("Zones.get_zone_geodataframe() returned None")

    SQL(f"DROP TABLE IF EXISTS {table_name};")
    SQL(f"""
        CREATE TABLE IF NOT EXISTS {table_name}(
            id TEXT,
            name TEXT,
            population DOUBLE,
            geometry TEXT, -- no geometry porque estamos en BRONZE LAYER
            -- Columnas extras añadidas para auditoria. 
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            -- loaded_by TEXT DEFAULT CURRENT_USER,
            source_file TEXT
        );
    """)

    SQL(f"""
        INSERT INTO {table_name}
        SELECT
            id,
            name,
            CAST(population AS DOUBLE) AS population,
            geometry,
            CURRENT_TIMESTAMP AS loaded_at,
            -- CURRENT_USER AS loaded_by,
            filename AS source_file
        FROM read_csv(
            '{dataset_path}/*.csv.gz',
            filename = true,
            all_varchar = true
        );
    """)

# %%
load_zones(type="distritos")
load_zones(type="municipios")
load_zones(type="gau")
# Out:
# Zones already downloaded. Reading the files....
# File /Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/raw/municipios/municipios_2.geojson already exists. Loading it...
# Zones already downloaded. Reading the files....
# File /Users/bgramaje/workspace/MUCEIM/bigdata/muceim-bigdata_project/raw/gau/gaus_2.geojson already exists. Loading it...

# %%
SQL("SELECT * FROM bronze_mitma_distritos LIMIT 5;")
# Out:
#          id                                 name  population  \
# 0     01001                     Alegría-Dulantzi      2925.0
# 1     01002                              Amurrio     10307.0
# 2  01004_AM  Artziniega agregacion de municipios      3005.0
# 3  01009_AM   Asparrena agregacion de municipios      4599.0
# 4     01010                          Ayala/Aiara      2951.0
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-2.534282365031893 42.78795118...
# 1  MULTIPOLYGON (((-2.975672535119074 42.93785360...
# 2  MULTIPOLYGON (((-3.140059301490131 43.16165242...
# 3  POLYGON ((-2.331385516435793 42.81775192629513...
# 4  POLYGON ((-3.000756145899012 43.06799670583464...
#
#                    loaded_at                    source_file
# 0 2025-11-16 10:22:38.514626  ../raw/distritos/zones.csv.gz
# 1 2025-11-16 10:22:38.514626  ../raw/distritos/zones.csv.gz
# 2 2025-11-16 10:22:38.514626  ../raw/distritos/zones.csv.gz
# 3 2025-11-16 10:22:38.514626  ../raw/distritos/zones.csv.gz
# 4 2025-11-16 10:22:38.514626  ../raw/distritos/zones.csv.gz

# %%
SQL("SELECT * FROM bronze_mitma_municipios LIMIT 5;")
# Out:
#          id                                 name  population  \
# 0     01001                     Alegría-Dulantzi      2925.0
# 1     01002                              Amurrio     10307.0
# 2  01004_AM  Artziniega agregacion de municipios      3005.0
# 3  01009_AM   Asparrena agregacion de municipios      4599.0
# 4     01010                          Ayala/Aiara      2951.0
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-2.537148430799974 42.78635536...
# 1  MULTIPOLYGON (((-2.976160717902642 42.93734039...
# 2  MULTIPOLYGON (((-3.137768037343801 43.16251541...
# 3  POLYGON ((-2.331385516435793 42.81775192629513...
# 4  POLYGON ((-3.000756145899012 43.06799670583464...
#
#                    loaded_at                     source_file
# 0 2025-11-16 10:22:48.482946  ../raw/municipios/zones.csv.gz
# 1 2025-11-16 10:22:48.482946  ../raw/municipios/zones.csv.gz
# 2 2025-11-16 10:22:48.482946  ../raw/municipios/zones.csv.gz
# 3 2025-11-16 10:22:48.482946  ../raw/municipios/zones.csv.gz
# 4 2025-11-16 10:22:48.482946  ../raw/municipios/zones.csv.gz

# %%
SQL("SELECT * FROM bronze_mitma_gau LIMIT 5;")
# Out:
#          id                                 name  population  \
# 0     01001                     Alegría-Dulantzi      2925.0
# 1     01002                              Amurrio     10307.0
# 2  01004_AM  Artziniega agregacion de municipios      3005.0
# 3  01009_AM   Asparrena agregacion de municipios      4599.0
# 4     01010                          Ayala/Aiara      2951.0
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-2.541390555095102 42.78538643...
# 1  MULTIPOLYGON (((-2.976906572483943 42.93701187...
# 2  MULTIPOLYGON (((-3.137673560842534 43.16203825...
# 3  POLYGON ((-2.331385516435793 42.81775192629513...
# 4  POLYGON ((-3.000756145899012 43.06799670583464...
#
#                    loaded_at              source_file
# 0 2025-11-16 10:22:57.754422  ../raw/gau/zones.csv.gz
# 1 2025-11-16 10:22:57.754422  ../raw/gau/zones.csv.gz
# 2 2025-11-16 10:22:57.754422  ../raw/gau/zones.csv.gz
# 3 2025-11-16 10:22:57.754422  ../raw/gau/zones.csv.gz
# 4 2025-11-16 10:22:57.754422  ../raw/gau/zones.csv.gz

# %%
con.close()
