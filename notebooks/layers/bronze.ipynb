# %%
# %pip install duckdb pandas numpy pyspainmobility requests

# %%
import duckdb
import pandas

BASE_PATH = '../../raw'
LAKE_LAYER = 'bronze'

con = duckdb.connect('../../mobility.db')


def SQL(q):
    """Run SQL (printed for clarity) and return a DataFrame."""
    return con.execute(q).fetchdf()


print("DuckDB version:", con.sql(
    "SELECT version();").fetchone()[0])  # type: ignore
# Out:
# DuckDB version: v1.4.2

# %% [markdown]
# ```sql
# -- viajes distristos
# -- se castea en vez de VARCHAR de 'si/no' a un booleano de true o false
# -- bronze_mitma_od_districts / bronze_mitma_viajes_distritos
# CREATE TABLE bronze_mitma_od_districts (
#     fecha TEXT,
#     periodo TEXT,
#     origen TEXT,
#     destino TEXT,
#     distancia TEXT,
#     actividad_origen TEXT,
#     actividad_destino TEXT,
#     residencia TEXT,
#     renta TEXT,
#     edad TEXT,
#     sexo TEXT,
#     viajes TEXT,
#     viajes_km TEXT,
#     -- Columnas extras añadidas para auditoria.
#     loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     -- loaded_by TEXT DEFAULT CURRENT_USER,
#     source_file TEXT
# );
#
# -- Viajes municipios
# -- bronze_mitma_od_municipalities / bronze_mitma_viajes_municipios
# CREATE TABLE bronze_mitma_od_municipalities (
#     fecha TEXT,
#     periodo TEXT,
#     origen TEXT,
#     destino TEXT,
#     distancia TEXT,
#     actividad_origen TEXT,
#     actividad_destino TEXT,
#     residencia TEXT,
#     renta TEXT,
#     edad TEXT,
#     sexo TEXT,
#     viajes TEXT,
#     viajes_km TEXT,
#     -- Columnas extras añadidas para auditoria.
#     loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     -- loaded_by TEXT DEFAULT CURRENT_USER,
#     source_file TEXT
# );
#
# -- Viajes GAU
# -- bronze_mitma_od_gau / bronze_mitma_viajes_gau
# CREATE TABLE bronze_mitma_od_gau (
#     fecha TEXT,
#     periodo TEXT,
#     origen TEXT,
#     destino TEXT,
#     distancia TEXT,
#     actividad_origen TEXT,
#     actividad_destino TEXT,
#     residencia TEXT,
#     renta TEXT,
#     edad TEXT,
#     sexo TEXT,
#     viajes TEXT,
#     viajes_km TEXT,
#     -- Columnas extras añadidas para auditoria.
#     loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     -- loaded_by TEXT DEFAULT CURRENT_USER,
#     source_file TEXT
# );
# ```

# %%
from pyspainmobility import Mobility
import os


def load_od_matrices(type="districts", start_date='2022-03-01', end_date='2022-03-03'):
    dataset = 'od'
    dataset_path = f'{BASE_PATH}/MITMA/{dataset}_{type}'
    full_path = os.path.abspath(dataset_path)

    table_name = f'{LAKE_LAYER}_mitma_{dataset}_{type}'

    os.makedirs(dataset_path, exist_ok=True)

    if not os.listdir(dataset_path):  # only download if the directory is empty
        data = Mobility(
            version=2,
            zones=type,
            start_date=start_date,
            end_date=end_date,
            output_directory=full_path,
        )

        data.get_od_data(keep_activity=True)

    SQL(f"DROP TABLE IF EXISTS {table_name};")
    SQL(f"""
        CREATE TABLE IF NOT EXISTS {table_name}(
            fecha TEXT,
            periodo TEXT,
            origen TEXT,
            destino TEXT,
            distancia TEXT,
            actividad_origen TEXT,
            actividad_destino TEXT,
            residencia TEXT,
            renta TEXT,
            edad TEXT,
            sexo TEXT,
            viajes TEXT,
            viajes_km TEXT,
            estudio_destino_posible TEXT,
            estudio_origen_posible TEXT,
            -- Columnas extras añadidas para auditoria. 
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            -- loaded_by TEXT DEFAULT CURRENT_USER,
            source_file TEXT
        );
    """)

    SQL(f"""
        INSERT INTO {table_name}
        SELECT
            fecha,
            periodo,
            origen,
            destino,
            distancia,
            actividad_origen,
            actividad_destino,
            residencia,
            renta,
            edad,
            sexo,
            viajes,
            viajes_km,
            estudio_destino_posible,
            estudio_origen_posible,
            CURRENT_TIMESTAMP AS loaded_at,
            -- CURRENT_USER AS loaded_by,
            filename AS source_file
        FROM read_csv(
            '{dataset_path}/*.csv.gz',
            filename = true,
            all_varchar = true
        );
 
""")

# %%
load_od_matrices(type="distritos")
load_od_matrices(type="municipios")
load_od_matrices(type="gau")
# Out:
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/viajes/ficheros-diarios/2022-03/20220301_Viajes_distritos.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/viajes/ficheros-diarios/2022-03/20220301_Viajes_distritos.csv.gz
# Saved 178582407 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_distritos/20220301_Viajes_distritos_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/viajes/ficheros-diarios/2022-03/20220302_Viajes_distritos.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/viajes/ficheros-diarios/2022-03/20220302_Viajes_distritos.csv.gz
# Saved 181734955 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_distritos/20220302_Viajes_distritos_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/viajes/ficheros-diarios/2022-03/20220303_Viajes_distritos.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/viajes/ficheros-diarios/2022-03/20220303_Viajes_distritos.csv.gz
# Saved 182421127 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_distritos/20220303_Viajes_distritos_v2.csv.gz
# Generating parquet file for ODs....
#   0%|          | 0/3 [00:00<?, ?it/s]
# Processing file: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_distritos/20220301_Viajes_distritos_v2.csv.gz
# Reading gzipped file...
#  33%|███▎      | 1/3 [00:46<01:33, 46.85s/it]
# Processing file: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_distritos/20220302_Viajes_distritos_v2.csv.gz
# Reading gzipped file...
#  67%|██████▋   | 2/3 [01:34<00:47, 47.38s/it]
# Processing file: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_distritos/20220303_Viajes_distritos_v2.csv.gz
# Reading gzipped file...
# 100%|██████████| 3/3 [02:22<00:00, 47.53s/it]
# Concatenating all the dataframes....
# Writing the parquet file....
# Parquet file generated successfully at  /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_distritos/Viajes_distritos_2022-03-01_2022-03-03_v2.parquet
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/viajes/ficheros-diarios/2022-03/20220301_Viajes_municipios.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/viajes/ficheros-diarios/2022-03/20220301_Viajes_municipios.csv.gz
# Saved 126098550 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_municipios/20220301_Viajes_municipios_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/viajes/ficheros-diarios/2022-03/20220302_Viajes_municipios.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/viajes/ficheros-diarios/2022-03/20220302_Viajes_municipios.csv.gz
# Saved 126682734 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_municipios/20220302_Viajes_municipios_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/viajes/ficheros-diarios/2022-03/20220303_Viajes_municipios.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/viajes/ficheros-diarios/2022-03/20220303_Viajes_municipios.csv.gz
# Saved 127116285 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_municipios/20220303_Viajes_municipios_v2.csv.gz
# Generating parquet file for ODs....
#   0%|          | 0/3 [00:00<?, ?it/s]
# Processing file: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_municipios/20220301_Viajes_municipios_v2.csv.gz
# Reading gzipped file...
#  33%|███▎      | 1/3 [00:27<00:55, 27.58s/it]
# Processing file: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_municipios/20220302_Viajes_municipios_v2.csv.gz
# Reading gzipped file...
#  67%|██████▋   | 2/3 [00:55<00:27, 27.61s/it]
# Processing file: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_municipios/20220303_Viajes_municipios_v2.csv.gz
# Reading gzipped file...
# 100%|██████████| 3/3 [01:23<00:00, 27.70s/it]
# Concatenating all the dataframes....
# Writing the parquet file....
# Parquet file generated successfully at  /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_municipios/Viajes_municipios_2022-03-01_2022-03-03_v2.parquet
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/viajes/ficheros-diarios/2022-03/20220301_Viajes_GAU.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/viajes/ficheros-diarios/2022-03/20220301_Viajes_GAU.csv.gz
# Saved 80051348 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_gau/20220301_Viajes_GAU_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/viajes/ficheros-diarios/2022-03/20220302_Viajes_GAU.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/viajes/ficheros-diarios/2022-03/20220302_Viajes_GAU.csv.gz
# Saved 79810781 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_gau/20220302_Viajes_GAU_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/viajes/ficheros-diarios/2022-03/20220303_Viajes_GAU.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/viajes/ficheros-diarios/2022-03/20220303_Viajes_GAU.csv.gz
# Saved 79881833 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_gau/20220303_Viajes_GAU_v2.csv.gz
# Generating parquet file for ODs....
#   0%|          | 0/3 [00:00<?, ?it/s]
# Processing file: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_gau/20220301_Viajes_GAU_v2.csv.gz
# Reading gzipped file...
#  33%|███▎      | 1/3 [00:17<00:34, 17.01s/it]
# Processing file: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_gau/20220302_Viajes_GAU_v2.csv.gz
# Reading gzipped file...
#  67%|██████▋   | 2/3 [00:34<00:17, 17.05s/it]
# Processing file: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_gau/20220303_Viajes_GAU_v2.csv.gz
# Reading gzipped file...
# 100%|██████████| 3/3 [00:51<00:00, 17.04s/it]
# Concatenating all the dataframes....
# Writing the parquet file....
# Parquet file generated successfully at  /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/od_gau/Viajes_GAU_2022-03-01_2022-03-03_v2.parquet

# %%
SQL(f"SELECT * FROM {LAKE_LAYER}_mitma_od_distritos LIMIT 5;")
# Out:
#       fecha periodo origen   destino distancia actividad_origen  \
# 0  20220301      08  01001     01002     10-50             casa
# 1  20220301      17  01001     01002     10-50     no_frecuente
# 2  20220301      00  01001  01009_AM      2-10             casa
# 3  20220301      00  01001  01009_AM      2-10        frecuente
# 4  20220301      02  01001  01009_AM      2-10             casa
#
#   actividad_destino residencia  renta edad sexo  viajes viajes_km  \
# 0         frecuente         01  10-15   NA   NA   2.764   125.486
# 1              casa         01  10-15   NA   NA   6.526   303.751
# 2         frecuente         01  10-15   NA   NA  10.279    67.832
# 3              casa         01    >15   NA   NA   4.591    42.419
# 4         frecuente         01  10-15   NA   NA   2.539    13.819
#
#   estudio_destino_posible estudio_origen_posible                  loaded_at  \
# 0                      no                     no 2025-11-17 18:45:47.564010
# 1                      no                     no 2025-11-17 18:45:47.564010
# 2                      no                     no 2025-11-17 18:45:47.564010
# 3                      no                     no 2025-11-17 18:45:47.564010
# 4                      no                     no 2025-11-17 18:45:47.564010
#
#                                          source_file
# 0  ../../raw/MITMA/od_distritos/20220301_Viajes_d...
# 1  ../../raw/MITMA/od_distritos/20220301_Viajes_d...
# 2  ../../raw/MITMA/od_distritos/20220301_Viajes_d...
# 3  ../../raw/MITMA/od_distritos/20220301_Viajes_d...
# 4  ../../raw/MITMA/od_distritos/20220301_Viajes_d...

# %%
# todo, altera table para llamar periodo a hora, esta la columna creada con periodo en vez de hora
SQL(f"""
    SELECT '{LAKE_LAYER}_mitma_od_distritos' as name, count(*) FROM {LAKE_LAYER}_mitma_od_distritos
    UNION
    SELECT '{LAKE_LAYER}_mitma_od_municipios' as name, count(*) FROM {LAKE_LAYER}_mitma_od_municipios
    UNION
    SELECT '{LAKE_LAYER}_mitma_od_gau' as name, count(*) FROM {LAKE_LAYER}_mitma_od_gau;
""")
# Out:
#                          name  count_star()
# 0  bronze_mitma_od_municipios      34684127
# 1         bronze_mitma_od_gau      20827473
# 2   bronze_mitma_od_distritos      55862966

# %% [markdown]
# ```sql
# -- Distritos
# CREATE TABLE IF NOT EXISTS bronze_mitma_people_day_districts (
#   fecha TEXT,
#   zona_pernoctacion TEXT,
#   edad TEXT,
#   sexo TEXT,
#   numero_viajes TEXT,   -- 0,1,2,2+ (mantener TEXT)
#   personas TEXT,
#   -- Columnas extras añadidas para auditoria.
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
# ```
# ```sql
# -- Municipios
# CREATE TABLE IF NOT EXISTS bronze_mitma_people_day_municipalities (
#   fecha TEXT,
#   zona_pernoctacion TEXT,
#   edad TEXT,
#   sexo TEXT,
#   numero_viajes TEXT,
#   personas TEXT,
#   -- Columnas extras añadidas para auditoria.
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
# ```
# ```sql
# -- GAU
# CREATE TABLE IF NOT EXISTS bronze_mitma_people_day_gau (
#   fecha TEXT,
#   zona_pernoctacion TEXT,
#   edad TEXT,
#   sexo TEXT,
#   numero_viajes TEXT,
#   personas TEXT,
#   -- Columnas extras añadidas para auditoria.
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
# ```

# %%
from pyspainmobility import Mobility
import os


def load_people_day(type="districts", start_date='2022-03-01', end_date='2022-03-03'):
    dataset = 'people_day'
    dataset_path = f'{BASE_PATH}/MITMA/{dataset}_{type}'
    full_path = os.path.abspath(dataset_path)

    table_name = f'{LAKE_LAYER}_mitma_{dataset}_{type}'

    os.makedirs(dataset_path, exist_ok=True)

    if not os.listdir(dataset_path):  # only download if the directory is empty
        data = Mobility(
            version=2,
            zones=type,
            start_date=start_date,
            end_date=end_date,
            output_directory=full_path,
        )

        data.get_number_of_trips_data()

    SQL(f"DROP TABLE IF EXISTS {table_name};")
    SQL(f"""
        CREATE TABLE IF NOT EXISTS {table_name}(
            fecha TEXT,
            zona_pernoctacion TEXT,
            edad TEXT,
            sexo TEXT,
            numero_viajes TEXT,
            personas TEXT,
            -- Columnas extras añadidas para auditoria. 
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            -- loaded_by TEXT DEFAULT CURRENT_USER,
            source_file TEXT
        );
    """)

    SQL(f"""
        INSERT INTO {table_name}
        SELECT
            fecha,
            zona_pernoctacion,
            edad,
            sexo,
            numero_viajes,
            personas,
            CURRENT_TIMESTAMP AS loaded_at,
            -- CURRENT_USER AS loaded_by,
            filename AS source_file
        FROM read_csv(
            '{dataset_path}/*.csv.gz',
            filename = true,
            all_varchar = true
        );
 
""")

# %%
load_people_day(type="distritos")
load_people_day(type="municipios")
load_people_day(type="gau")
# Out:
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/personas/ficheros-diarios/2022-03/20220301_Personas_dia_distritos.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/personas/ficheros-diarios/2022-03/20220301_Personas_dia_distritos.csv.gz
# Saved 784312 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_distritos/20220301_Personas_distritos_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/personas/ficheros-diarios/2022-03/20220302_Personas_dia_distritos.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/personas/ficheros-diarios/2022-03/20220302_Personas_dia_distritos.csv.gz
# Saved 774109 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_distritos/20220302_Personas_distritos_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/personas/ficheros-diarios/2022-03/20220303_Personas_dia_distritos.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/personas/ficheros-diarios/2022-03/20220303_Personas_dia_distritos.csv.gz
# Saved 773512 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_distritos/20220303_Personas_distritos_v2.csv.gz
# Generating parquet file for Number of Trips....
# 100%|██████████| 3/3 [00:00<00:00, 12.61it/s]
# Concatenating all the dataframes....
# Writing the parquet file....
# Parquet file generated successfully at  /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_distritos/Personas_distritos_2022-03-01_2022-03-03_v2.parquet
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/personas/ficheros-diarios/2022-03/20220301_Personas_dia_municipios.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/personas/ficheros-diarios/2022-03/20220301_Personas_dia_municipios.csv.gz
# Saved 530935 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_municipios/20220301_Personas_municipios_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/personas/ficheros-diarios/2022-03/20220302_Personas_dia_municipios.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/personas/ficheros-diarios/2022-03/20220302_Personas_dia_municipios.csv.gz
# Saved 522530 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_municipios/20220302_Personas_municipios_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/personas/ficheros-diarios/2022-03/20220303_Personas_dia_municipios.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/personas/ficheros-diarios/2022-03/20220303_Personas_dia_municipios.csv.gz
# Saved 521975 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_municipios/20220303_Personas_municipios_v2.csv.gz
# Generating parquet file for Number of Trips....
# 100%|██████████| 3/3 [00:00<00:00, 18.42it/s]
# Concatenating all the dataframes....
# Writing the parquet file....
# Parquet file generated successfully at  /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_municipios/Personas_municipios_2022-03-01_2022-03-03_v2.parquet
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/personas/ficheros-diarios/2022-03/20220301_Personas_dia_GAU.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/personas/ficheros-diarios/2022-03/20220301_Personas_dia_GAU.csv.gz
# Saved 418238 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_gau/20220301_Personas_GAU_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/personas/ficheros-diarios/2022-03/20220302_Personas_dia_GAU.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/personas/ficheros-diarios/2022-03/20220302_Personas_dia_GAU.csv.gz
# Saved 410613 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_gau/20220302_Personas_GAU_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/personas/ficheros-diarios/2022-03/20220303_Personas_dia_GAU.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/personas/ficheros-diarios/2022-03/20220303_Personas_dia_GAU.csv.gz
# Saved 409507 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_gau/20220303_Personas_GAU_v2.csv.gz
# Generating parquet file for Number of Trips....
# 100%|██████████| 3/3 [00:00<00:00, 23.02it/s]
# Concatenating all the dataframes....
# Writing the parquet file....
# Parquet file generated successfully at  /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/people_day_gau/Personas_GAU_2022-03-01_2022-03-03_v2.parquet

# %%
SQL("SELECT * FROM bronze_mitma_people_day_distritos LIMIT 5;")
# Out:
#       fecha zona_pernoctacion  edad    sexo numero_viajes personas  \
# 0  20220301             01001  0-25  hombre             0  125.296
# 1  20220301             01001  0-25  hombre             2  115.378
# 2  20220301             01001  0-25  hombre            2+  176.630
# 3  20220301             01001  0-25   mujer             0  125.069
# 4  20220301             01001  0-25   mujer             2  117.712
#
#                    loaded_at  \
# 0 2025-11-17 19:24:15.390091
# 1 2025-11-17 19:24:15.390091
# 2 2025-11-17 19:24:15.390091
# 3 2025-11-17 19:24:15.390091
# 4 2025-11-17 19:24:15.390091
#
#                                          source_file
# 0  ../../raw/MITMA/people_day_distritos/20220301_...
# 1  ../../raw/MITMA/people_day_distritos/20220301_...
# 2  ../../raw/MITMA/people_day_distritos/20220301_...
# 3  ../../raw/MITMA/people_day_distritos/20220301_...
# 4  ../../raw/MITMA/people_day_distritos/20220301_...

# %%
SQL(f"""
    SELECT '{LAKE_LAYER}_mitma_people_day_distritos' as name, count(*) FROM {LAKE_LAYER}_mitma_people_day_distritos
    UNION
    SELECT '{LAKE_LAYER}_mitma_people_day_municipios' as name, count(*) FROM {LAKE_LAYER}_mitma_people_day_municipios
    UNION
    SELECT '{LAKE_LAYER}_mitma_people_day_gau' as name, count(*) FROM {LAKE_LAYER}_mitma_people_day_gau;
""")
# Out:
#                                  name  count_star()
# 0   bronze_mitma_people_day_distritos        340448
# 1         bronze_mitma_people_day_gau        182214
# 2  bronze_mitma_people_day_municipios        231688

# %% [markdown]
# ```sql
# -- Distritos
# CREATE TABLE IF NOT EXISTS bronze_mitma_overnight_stay_districts (
#   fecha TEXT,
#   zona_residencia TEXT,
#   zona_pernoctacion TEXT,
#   personas TEXT,
#   -- Columnas extras añadidas para auditoria.
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
# ```
#
# ```sql
# -- Municipios
# CREATE TABLE IF NOT EXISTS bronze_mitma_overnight_stay_municipalities (
#   fecha TEXT,
#   zona_residencia TEXT,
#   zona_pernoctacion TEXT,
#   personas TEXT,
#   -- Columnas extras añadidas para auditoria.
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
# ```
#
# ```sql
# -- GAU
# CREATE TABLE IF NOT EXISTS bronze_mitma_overnight_stay_gau (
#   fecha TEXT,
#   zona_residencia TEXT,
#   zona_pernoctacion TEXT,
#   personas TEXT,
#   -- Columnas extras añadidas para auditoria.
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
# ```

# %%
from pyspainmobility import Mobility
import os


def load_overnight_stay(type="districts", start_date='2022-03-01', end_date='2022-03-03'):
    dataset = 'overnight_stay'
    dataset_path = f'{BASE_PATH}/MITMA/{dataset}_{type}'
    full_path = os.path.abspath(dataset_path)

    table_name = f'{LAKE_LAYER}_mitma_{dataset}_{type}'

    os.makedirs(dataset_path, exist_ok=True)

    if not os.listdir(dataset_path):  # only download if the directory is empty
        data = Mobility(
            version=2,
            zones=type,
            start_date=start_date,
            end_date=end_date,
            output_directory=full_path,
        )
        data.get_overnight_stays_data()

    SQL(f"DROP TABLE IF EXISTS {table_name};")
    SQL(f"""
        CREATE TABLE IF NOT EXISTS {table_name}(
            fecha TEXT,
            zona_residencia TEXT,
            zona_pernoctacion TEXT,
            personas TEXT,
            -- Columnas extras añadidas para auditoria. 
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            -- loaded_by TEXT DEFAULT CURRENT_USER,
            source_file TEXT
        );
    """)

    SQL(f"""
        INSERT INTO {table_name}
        SELECT
            fecha,
            zona_residencia,
            zona_pernoctacion,
            personas,
            CURRENT_TIMESTAMP AS loaded_at,
            -- CURRENT_USER AS loaded_by,
            filename AS source_file
        FROM read_csv(
            '{dataset_path}/*.csv.gz',
            filename = true,
            all_varchar = true
        );
 
""")

# %%
load_overnight_stay(type="distritos")
load_overnight_stay(type="municipios")
load_overnight_stay(type="gau")
# Out:
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/pernoctaciones/ficheros-diarios/2022-03/20220301_Pernoctaciones_distritos.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/pernoctaciones/ficheros-diarios/2022-03/20220301_Pernoctaciones_distritos.csv.gz
# Saved 1853342 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_distritos/20220301_Pernoctaciones_distritos_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/pernoctaciones/ficheros-diarios/2022-03/20220302_Pernoctaciones_distritos.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/pernoctaciones/ficheros-diarios/2022-03/20220302_Pernoctaciones_distritos.csv.gz
# Saved 1643373 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_distritos/20220302_Pernoctaciones_distritos_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/pernoctaciones/ficheros-diarios/2022-03/20220303_Pernoctaciones_distritos.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-distritos/pernoctaciones/ficheros-diarios/2022-03/20220303_Pernoctaciones_distritos.csv.gz
# Saved 1623621 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_distritos/20220303_Pernoctaciones_distritos_v2.csv.gz
# Generating parquet file for Overnight Stays....
# 100%|██████████| 3/3 [00:00<00:00,  8.77it/s]
# Concatenating all the dataframes....
# Writing the parquet file....
# Parquet file generated successfully at  /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_distritos/Pernoctaciones_distritos_2022-03-01_2022-03-03_v2.parquet
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/pernoctaciones/ficheros-diarios/2022-03/20220301_Pernoctaciones_municipios.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/pernoctaciones/ficheros-diarios/2022-03/20220301_Pernoctaciones_municipios.csv.gz
# Saved 1468082 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_municipios/20220301_Pernoctaciones_municipios_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/pernoctaciones/ficheros-diarios/2022-03/20220302_Pernoctaciones_municipios.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/pernoctaciones/ficheros-diarios/2022-03/20220302_Pernoctaciones_municipios.csv.gz
# Saved 1297818 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_municipios/20220302_Pernoctaciones_municipios_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/pernoctaciones/ficheros-diarios/2022-03/20220303_Pernoctaciones_municipios.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-municipios/pernoctaciones/ficheros-diarios/2022-03/20220303_Pernoctaciones_municipios.csv.gz
# Saved 1275954 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_municipios/20220303_Pernoctaciones_municipios_v2.csv.gz
# Generating parquet file for Overnight Stays....
# 100%|██████████| 3/3 [00:00<00:00, 10.51it/s]
# Concatenating all the dataframes....
# Writing the parquet file....
# Parquet file generated successfully at  /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_municipios/Pernoctaciones_municipios_2022-03-01_2022-03-03_v2.parquet
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/pernoctaciones/ficheros-diarios/2022-03/20220301_Pernoctaciones_GAU.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/pernoctaciones/ficheros-diarios/2022-03/20220301_Pernoctaciones_GAU.csv.gz
# Saved 1255035 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_gau/20220301_Pernoctaciones_GAU_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/pernoctaciones/ficheros-diarios/2022-03/20220302_Pernoctaciones_GAU.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/pernoctaciones/ficheros-diarios/2022-03/20220302_Pernoctaciones_GAU.csv.gz
# Saved 1099165 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_gau/20220302_Pernoctaciones_GAU_v2.csv.gz
# Downloading file from https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/pernoctaciones/ficheros-diarios/2022-03/20220303_Pernoctaciones_GAU.csv.gz
# Downloading: https://movilidad-opendata.mitma.es/estudios_basicos/por-GAU/pernoctaciones/ficheros-diarios/2022-03/20220303_Pernoctaciones_GAU.csv.gz
# Saved 1075934 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_gau/20220303_Pernoctaciones_GAU_v2.csv.gz
# Generating parquet file for Overnight Stays....
# 100%|██████████| 3/3 [00:00<00:00, 12.25it/s]
# Concatenating all the dataframes....
# Writing the parquet file....
# Parquet file generated successfully at  /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/overnight_stay_gau/Pernoctaciones_GAU_2022-03-01_2022-03-03_v2.parquet

# %%
SQL("SELECT * FROM bronze_mitma_overnight_stay_distritos LIMIT 5;")
# Out:
#       fecha zona_residencia zona_pernoctacion  personas  \
# 0  20220301           01001             01001  2733.784
# 1  20220301           01001          01004_AM     2.514
# 2  20220301           01001          01009_AM    18.431
# 3  20220301           01001          01017_AM     2.922
# 4  20220301           01001             01051     7.831
#
#                    loaded_at  \
# 0 2025-11-17 19:27:43.023159
# 1 2025-11-17 19:27:43.023159
# 2 2025-11-17 19:27:43.023159
# 3 2025-11-17 19:27:43.023159
# 4 2025-11-17 19:27:43.023159
#
#                                          source_file
# 0  ../../raw/MITMA/overnight_stay_distritos/20220...
# 1  ../../raw/MITMA/overnight_stay_distritos/20220...
# 2  ../../raw/MITMA/overnight_stay_distritos/20220...
# 3  ../../raw/MITMA/overnight_stay_distritos/20220...
# 4  ../../raw/MITMA/overnight_stay_distritos/20220...

# %%
SQL(f"""
    SELECT '{LAKE_LAYER}_mitma_overnight_stay_distritos' as name, count(*) FROM {LAKE_LAYER}_mitma_overnight_stay_distritos
    UNION
    SELECT '{LAKE_LAYER}_mitma_overnight_stay_municipios' as name, count(*) FROM {LAKE_LAYER}_mitma_overnight_stay_municipios
    UNION
    SELECT '{LAKE_LAYER}_mitma_overnight_stay_gau' as name, count(*) FROM {LAKE_LAYER}_mitma_overnight_stay_gau;
""")
# Out:
#                                      name  count_star()
# 0   bronze_mitma_overnight_stay_distritos        947839
# 1  bronze_mitma_overnight_stay_municipios        741266
# 2         bronze_mitma_overnight_stay_gau        574703

# %% [markdown]
# ```sql
# -- Distritos
# CREATE TABLE IF NOT EXISTS bronze_mitma_districts (
#   id TEXT,
#   name TEXT,
#   population TEXT,
#   geometry TEXT,
#   -- Columnas extras añadidas para auditoria.
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
# ```
#
# ```sql
# -- Municipios
# CREATE TABLE IF NOT EXISTS bronze_mitma_municipalities (
#   id TEXT,
#   name TEXT,
#   population TEXT,
#   geometry TEXT,
#   -- Columnas extras añadidas para auditoria.
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
# ```
#
# ```sql
# -- GAU
# CREATE TABLE IF NOT EXISTS bronze_mitma_gau (
#   id TEXT,
#   name TEXT,
#   population TEXT,
#   geometry TEXT,
#   -- Columnas extras añadidas para auditoria.
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   source_file TEXT
# );
# ```

# %%
# %load_ext autoreload

# %%
# %autoreload 2
# pyspain tiene un bug para descargar las zonas, asi que lo parcheamos aqui.
# hay que meterse en el Zones.py del codigo fuente y cambiar las lineas 129, 134, 141.
# para poner esto os.path.join(self.output_path, "el file que sea"), en vez de os.path.join(data_directory, "el file que sea")
from pyspainmobility import Zones
import os
import pandas as pd

def load_zones(type = "districts"):
    dataset_path = f'{BASE_PATH}/MITMA/{type}'
    table_name = f'{LAKE_LAYER}_mitma_{type}'
    full_path = os.path.abspath(dataset_path)

    os.makedirs(dataset_path, exist_ok=True)
    
    if(not os.path.isfile(f'{dataset_path}/zones.csv.gz')):
        data = Zones(
                version=2,
                zones=type,
                output_directory=full_path,
            )
        
        dfdata = data.get_zone_geodataframe()
        # ya que no nos devuelve un csv, lo guardamos y además comprimido
        if dfdata is not None:
            print(dfdata.head())
            dfdata.to_csv(f'{dataset_path}/zones.csv.gz', index=True, compression='gzip')
        else:
            raise ValueError("Zones.get_zone_geodataframe() returned None")
    
    SQL(f"DROP TABLE IF EXISTS {table_name};")
    SQL(f"""
        CREATE TABLE IF NOT EXISTS {table_name}(
            id TEXT,
            name TEXT,
            population TEXT,
            geometry TEXT, -- no geometry porque estamos en BRONZE LAYER
            -- Columnas extras añadidas para auditoria. 
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            -- loaded_by TEXT DEFAULT CURRENT_USER,
            source_file TEXT
        );
    """)

    SQL(f"""
        INSERT INTO {table_name}
        SELECT
            id,
            name,
            population,
            geometry,
            CURRENT_TIMESTAMP AS loaded_at,
            -- CURRENT_USER AS loaded_by,
            filename AS source_file
        FROM read_csv(
            '{dataset_path}/*.csv.gz',
            filename = true,
            all_varchar = true
        );
    """)

# %%
load_zones(type="distritos")
load_zones(type="municipios")
load_zones(type="gau")
# Out:
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/poblacion.csv
# Saved 97707 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/poblacion.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/relacion_ine_zonificacionMitma.csv
# Saved 1919214 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/relacion_ine_zonificacionMitma.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos_centroides.qpj
# Saved 618 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos_centroides.qpj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos_centroides.shp
# Saved 109552 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos_centroides.shp
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos_centroides.shx
# Saved 31372 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos_centroides.shx
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos.shx
# Saved 31372 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos.shx
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos_centroides.cpg
# Saved 5 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos_centroides.cpg
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos_centroides.dbf
# Saved 316695 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos_centroides.dbf
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos_centroides.prj
# Saved 393 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos_centroides.prj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/nombres_distritos.csv
# Saved 124729 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/nombres_distritos.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/poblacion_distritos.csv
# Saved 60473 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/poblacion_distritos.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos.cpg
# Saved 5 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos.cpg
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos.dbf
# Saved 316695 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos.dbf
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos.prj
# Saved 393 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos.prj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos.qpj
# Saved 618 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos.qpj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos.shp
# Saved 23410552 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos.shp
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos_centroides.qmd
# Saved 650 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos_centroides.qmd
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_distritos/zonificacion_distritos.qmd
# Saved 657 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos.qmd
# Zones already downloaded. Reading the files....
# /home/bgramaje/workspace/MUCEIM/bigdata/project/.venv/lib/python3.10/site-packages/pyogrio/raw.py:198: RuntimeWarning: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/distritos/zonificacion_distritos.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
#                                          name population  \
# id
# 01001                        Alegría-Dulantzi     2925.0
# 01002                                 Amurrio    10307.0
# 01004_AM  Artziniega agregacion de municipios     3005.0
# 01009_AM   Asparrena agregacion de municipios     4599.0
# 01010                             Ayala/Aiara     2951.0
#
#                                                    geometry
# id
# 01001     MULTIPOLYGON (((-2.53428 42.78795, -2.53715 42...
# 01002     MULTIPOLYGON (((-2.97567 42.93785, -2.97616 42...
# 01004_AM  MULTIPOLYGON (((-3.14006 43.16165, -3.13777 43...
# 01009_AM  POLYGON ((-2.33139 42.81775, -2.3319 42.81729,...
# 01010     POLYGON ((-3.00076 43.068, -3.00853 43.06362, ...
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/poblacion.csv
# Saved 97707 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/poblacion.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/relacion_ine_zonificacionMitma.csv
# Saved 1919214 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/relacion_ine_zonificacionMitma.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios_centroides.prj
# Saved 393 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios_centroides.prj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios_centroides.qpj
# Saved 618 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios_centroides.qpj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios_centroides.shp
# Saved 76680 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios_centroides.shp
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios_centroides.shx
# Saved 21980 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios_centroides.shx
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios.shx
# Saved 21980 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios.shx
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios_centroides.cpg
# Saved 5 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios_centroides.cpg
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios_centroides.dbf
# Saved 221601 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios_centroides.dbf
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios.prj
# Saved 393 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios.prj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios.qpj
# Saved 618 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios.qpj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios.shp
# Saved 21421124 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios.shp
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/nombres_municipios.csv
# Saved 91538 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/nombres_municipios.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/poblacion_municipios.csv
# Saved 40360 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/poblacion_municipios.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios.cpg
# Saved 5 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios.cpg
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_municipios/zonificacion_municipios.dbf
# Saved 221601 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios.dbf
# Zones already downloaded. Reading the files....
# /home/bgramaje/workspace/MUCEIM/bigdata/project/.venv/lib/python3.10/site-packages/pyogrio/raw.py:198: RuntimeWarning: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/municipios/zonificacion_municipios.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
#                                          name population  \
# id
# 01001                        Alegría-Dulantzi     2925.0
# 01002                                 Amurrio    10307.0
# 01004_AM  Artziniega agregacion de municipios     3005.0
# 01009_AM   Asparrena agregacion de municipios     4599.0
# 01010                             Ayala/Aiara     2951.0
#
#                                                    geometry
# id
# 01001     MULTIPOLYGON (((-2.53715 42.78636, -2.54139 42...
# 01002     MULTIPOLYGON (((-2.97616 42.93734, -2.97691 42...
# 01004_AM  MULTIPOLYGON (((-3.13777 43.16252, -3.13767 43...
# 01009_AM  POLYGON ((-2.33139 42.81775, -2.3319 42.81729,...
# 01010     POLYGON ((-3.00076 43.068, -3.00853 43.06362, ...
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/poblacion.csv
# Saved 97707 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/poblacion.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/relacion_ine_zonificacionMitma.csv
# Saved 1919214 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/relacion_ine_zonificacionMitma.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus_centroides.cpg
# Saved 5 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus_centroides.cpg
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus_centroides.dbf
# Saved 178509 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus_centroides.dbf
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus_centroides.prj
# Saved 393 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus_centroides.prj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus_centroides.qpj
# Saved 618 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus_centroides.qpj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus_centroides.shp
# Saved 61784 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus_centroides.shp
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus_centroides.shx
# Saved 17724 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus_centroides.shx
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus.shx
# Saved 17724 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus.shx
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/nombres_gaus.csv
# Saved 68993 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/nombres_gaus.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/poblacion_gaus.csv
# Saved 33393 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/poblacion_gaus.csv
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus.cpg
# Saved 5 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus.cpg
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus.dbf
# Saved 178509 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus.dbf
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus.prj
# Saved 393 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus.prj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus.qpj
# Saved 618 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus.qpj
# Downloading necessary files....
# Downloading: https://movilidad-opendata.mitma.es/zonificacion/zonificacion_GAU/zonificacion_gaus.shp
# Saved 20057808 bytes to /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus.shp
# Zones already downloaded. Reading the files....
# /home/bgramaje/workspace/MUCEIM/bigdata/project/.venv/lib/python3.10/site-packages/pyogrio/raw.py:198: RuntimeWarning: /home/bgramaje/workspace/MUCEIM/bigdata/project/raw/MITMA/gau/zonificacion_gaus.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
#                                          name population  \
# id
# 01001                        Alegría-Dulantzi     2925.0
# 01002                                 Amurrio    10307.0
# 01004_AM  Artziniega agregacion de municipios     3005.0
# 01009_AM   Asparrena agregacion de municipios     4599.0
# 01010                             Ayala/Aiara     2951.0
#
#                                                    geometry
# id
# 01001     MULTIPOLYGON (((-2.54139 42.78539, -2.54435 42...
# 01002     MULTIPOLYGON (((-2.97691 42.93701, -2.97702 42...
# 01004_AM  MULTIPOLYGON (((-3.13767 43.16204, -3.13719 43...
# 01009_AM  POLYGON ((-2.33139 42.81775, -2.3319 42.81729,...
# 01010     POLYGON ((-3.00076 43.068, -3.00853 43.06362, ...

# %%
SQL("""
    SELECT 'bronze_mitma_distritos' as name, count(*) FROM bronze_mitma_distritos
    UNION
    SELECT 'bronze_mitma_municipios' as name, count(*) FROM bronze_mitma_municipios
    UNION
    SELECT 'bronze_mitma_gau' as name, count(*) FROM bronze_mitma_gau;
""")
# Out:
#                       name  count_star()
# 0  bronze_mitma_municipios          2618
# 1         bronze_mitma_gau          2086
# 2   bronze_mitma_distritos          3792

# %% [markdown]
# ```sql
# -- Distritos
# CREATE TABLE IF NOT EXISTS bronze_ine_padron_municipios (
#   cod        VARCHAR,
#   nombre     VARCHAR,
#   fk_unidad  INTEGER,
#   fk_escala  INTEGER,
#   data_txt   TEXT,
#   data       JSON,
#   -- Columnas extras añadidas para auditoria.
#   loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#   -- loaded_by TEXT DEFAULT CURRENT_USER,
#   source_file TEXT
# );

# %%
import requests
import pandas as pd


def get_padron_by_municipio(year: int):
    url = f"https://servicios.ine.es/wstempus/js/ES/DATOS_TABLA/29005?date={year}0101:{year}1231"

    response = requests.get(url, timeout=120)
    data = response.json()

    df = pd.json_normalize(data)
    return df


def load_padron(year=2023):
    dataset_path = f'{BASE_PATH}/INE/padron_municipios'
    table_name = f'{LAKE_LAYER}_ine_padron_municipios'

    filename = f'padron_municipios_{year}.csv.gz'

    os.makedirs(dataset_path, exist_ok=True)

    if (not os.path.isfile(f'{dataset_path}/{filename}')):
        df = get_padron_by_municipio(year)
        # ya que no nos devuelve un csv, lo guardamos y además comprimido
        if df is not None:
            df.to_csv(f"{dataset_path}/{filename}",
                      index=False, compression='gzip')
        else:
            raise ValueError("Zones.get_zone_geodataframe() returned None")

    SQL(f"DROP TABLE IF EXISTS {table_name};")
    SQL(f"""
        CREATE TABLE IF NOT EXISTS {table_name}(
            cod        VARCHAR,
            nombre     VARCHAR,
            fk_unidad  INTEGER,
            fk_escala  INTEGER,
            data_txt   TEXT,
            data       JSON,
            -- Columnas extras añadidas para auditoria. 
            loaded_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            -- loaded_by TEXT DEFAULT CURRENT_USER,
            source_file TEXT
        );
    """)

    SQL(f"""
        INSERT INTO {table_name}
        SELECT
            COD        AS cod,
            Nombre     AS nombre,
            FK_Unidad::INTEGER AS fk_unidad,
            FK_Escala::INTEGER AS fk_escala,
            REGEXP_REPLACE(
                REGEXP_REPLACE(
                    REGEXP_REPLACE(
                        REPLACE(data, '''', '"'),
                        '\\bTrue\\b', 'true'
                        ),
                        '\\bFalse\\b', 'false'
                ),
                '\\bNone\\b', 'null'
            ) AS data_txt,
            CAST(data_txt AS JSON) AS data,
            CURRENT_TIMESTAMP AS loaded_at,
            -- CURRENT_USER AS loaded_by,
            filename AS source_file
        FROM read_csv(
            '{dataset_path}/{filename}',
            filename = true,
            all_varchar = true
        );
    """)

# %%
load_padron(2023)

# %%
SQL("SELECT * FROM bronze_ine_padron_municipios LIMIT 5;")
# Out:
#          cod                                         nombre  fk_unidad  \
# 0  DPOP19723    Ababuj. Total. Total habitantes. Personas.           3
# 1  DPOP19724  Ababuj. Hombres. Total habitantes. Personas.           3
# 2  DPOP19725  Ababuj. Mujeres. Total habitantes. Personas.           3
# 3  DPOP17671    Abades. Total. Total habitantes. Personas.           3
# 4  DPOP17672  Abades. Hombres. Total habitantes. Personas.           3
#
#    fk_escala                                           data_txt  \
# 0          1  [{"Fecha": 1672527600000, "FK_TipoDato": 1, "F...
# 1          1  [{"Fecha": 1672527600000, "FK_TipoDato": 1, "F...
# 2          1  [{"Fecha": 1672527600000, "FK_TipoDato": 1, "F...
# 3          1  [{"Fecha": 1672527600000, "FK_TipoDato": 1, "F...
# 4          1  [{"Fecha": 1672527600000, "FK_TipoDato": 1, "F...
#
#                                                 data  \
# 0  [{"Fecha": 1672527600000, "FK_TipoDato": 1, "F...
# 1  [{"Fecha": 1672527600000, "FK_TipoDato": 1, "F...
# 2  [{"Fecha": 1672527600000, "FK_TipoDato": 1, "F...
# 3  [{"Fecha": 1672527600000, "FK_TipoDato": 1, "F...
# 4  [{"Fecha": 1672527600000, "FK_TipoDato": 1, "F...
#
#                    loaded_at  \
# 0 2025-11-17 19:31:37.860616
# 1 2025-11-17 19:31:37.860616
# 2 2025-11-17 19:31:37.860616
# 3 2025-11-17 19:31:37.860616
# 4 2025-11-17 19:31:37.860616
#
#                                          source_file
# 0  ../../raw/INE/padron_municipios/padron_municip...
# 1  ../../raw/INE/padron_municipios/padron_municip...
# 2  ../../raw/INE/padron_municipios/padron_municip...
# 3  ../../raw/INE/padron_municipios/padron_municip...
# 4  ../../raw/INE/padron_municipios/padron_municip...

# %%
import requests
import pandas as pd


def get_poblacion_quinq_by_municipio(year: int) -> pd.DataFrame:
    # Tabla 33974: "Población por sexo, municipios y edad (grupos quinquenales)" (Padrón Continuo)
    # tip=A fuerza periodicidad anual; tv=periodo:<YYYY> filtra al año solicitado
    url = f"https://servicios.ine.es/wstempus/js/ES/DATOS_TABLA/68535?nult=1&tip=A&date={year}0101:{year}1231"
    print("Fetching data from URL:", url)
    resp = requests.get(url, timeout=180)
    resp.raise_for_status()
    data = resp.json()
    df = pd.json_normalize(data)
    return df


df = get_poblacion_quinq_by_municipio(2023)
df.head()
# Out:
# Fetching data from URL: https://servicios.ine.es/wstempus/js/ES/DATOS_TABLA/68535?nult=1&tip=A&date=20230101:20231231
#                                             status
# 0  No puede mostrarse por restricciones de volumen

# %%
con.close()
